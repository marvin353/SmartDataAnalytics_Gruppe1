# %% [markdown]
# # Data Exploration
#
# ## Imports

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import seaborn as sns

colors = {0:'tab:blue',1:'tab:orange',2:'tab:green'}

#font = {'family' : 'normal',
#        'weight' : 'bold',
#        'size'   : 22}

#matplotlib.rc('font', **font)

# %%
with open('data.pickle', 'rb') as handle:
    data = pickle.load(handle)

df = pd.read_pickle("data.pickle")

# %%
df
# Out:
#              id   run               timestamp  segment          start_time  \
# 0         163.0   0.0 2017-05-30 09:21:13.150     11.0 2017-05-30 09:21:05
# 1         164.0   0.0 2017-05-30 09:21:13.200     11.0 2017-05-30 09:21:05
# 2         165.0   0.0 2017-05-30 09:21:13.250     11.0 2017-05-30 09:21:05
# 3         166.0   0.0 2017-05-30 09:21:13.300     11.0 2017-05-30 09:21:05
# 4         167.0   0.0 2017-05-30 09:21:13.350     11.0 2017-05-30 09:21:05
# ...         ...   ...                     ...      ...                 ...
# 41890  128835.0  73.0 2017-05-30 11:23:04.500  10071.0 2017-05-30 11:21:46
# 41891  128836.0  73.0 2017-05-30 11:23:04.550  10071.0 2017-05-30 11:21:46
# 41892  128837.0  73.0 2017-05-30 11:23:04.600  10071.0 2017-05-30 11:21:46
# 41893  128838.0  73.0 2017-05-30 11:23:04.650  10071.0 2017-05-30 11:21:46
# 41894  128839.0  73.0 2017-05-30 11:23:04.700  10071.0 2017-05-30 11:21:46
#
#                      end_time   force_x   force_y   force_z       pos_x  \
# 0     2017-05-30 09:22:41.607 -0.543045 -2.924596 -7.257000 -257.695704
# 1     2017-05-30 09:22:41.607 -0.465969 -3.278856 -7.522000 -257.617629
# 2     2017-05-30 09:22:41.607 -0.317475 -3.435834 -7.705999 -256.626803
# 3     2017-05-30 09:22:41.607 -0.298383 -3.457754 -7.580999 -254.594017
# 4     2017-05-30 09:22:41.607 -0.289898 -3.447854 -7.539000 -251.411919
# ...                       ...       ...       ...       ...         ...
# 41890 2017-05-30 11:23:20.234 -0.002031 -0.027602  0.034985  -57.374833
# 41891 2017-05-30 11:23:20.234  0.002973 -0.022673  0.075981  -57.362208
# 41892 2017-05-30 11:23:20.234 -0.032581 -0.015567 -0.048960  -57.417483
# 41893 2017-05-30 11:23:20.234 -0.021910 -0.026181 -0.015984  -57.481887
# 41894 2017-05-30 11:23:20.234 -0.171863  0.010391 -0.014732  -57.418634
#
#             pos_y       pos_z       rot_x       rot_y       rot_z result_robot
# 0     -265.980105  240.007357   -0.008832    0.034723  179.958414      Success
# 1     -265.999590  240.004745   -0.000171    0.019928  179.968161      Success
# 2     -266.602650  239.791224 -179.993978  179.989304    0.164766      Success
# 3     -267.926090  239.323013 -179.992478  179.999036    0.577883      Success
# 4     -269.894497  238.550625 -179.996649  179.988091    1.210269      Success
# ...           ...         ...         ...         ...         ...          ...
# 41890 -317.029408  231.103605 -179.993475 -179.986587   44.930087      Success
# 41891 -317.035132  230.987210 -179.983260 -179.989815   44.932791      Success
# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41895 entries, 0 to 41894
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            41895 non-null  float64
#  1   run           41895 non-null  float64
#  2   timestamp     41895 non-null  datetime64[ns]
#  3   segment       41895 non-null  float64
#  4   start_time    41895 non-null  datetime64[ns]
#  5   end_time      41895 non-null  datetime64[ns]
#  6   force_x       41895 non-null  float64
#  7   force_y       41895 non-null  float64
#  8   force_z       41895 non-null  float64
#  9   pos_x         41895 non-null  float64
#  10  pos_y         41895 non-null  float64
#  11  pos_z         41895 non-null  float64
#  12  rot_x         41895 non-null  float64
#  13  rot_y         41895 non-null  float64
#  14  rot_z         41895 non-null  float64
#  15  result_robot  41895 non-null  object
# dtypes: datetime64[ns](3), float64(12), object(1)
# memory usage: 6.4+ MB

# %%
# Sccess - Fail Distribution
plt.rc('xtick', labelsize=10)    # fontsize of the tick labels
plt.rc('ytick', labelsize=10)
ax = sns.countplot(x="result_robot", data=df)
plt.show()
# Seems like success only

# Distribution by: run
fig = plt.figure(figsize=(30,8))
plt.rc('xtick', labelsize=22)    # fontsize of the tick labels
plt.rc('ytick', labelsize=22)
plt.xticks(rotation=90)
ax = sns.countplot(x="run", data=df)
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
run_0_df = df[df['run'] == 0.0]
print(run_0_df['segment'].unique())

for i in range(int(len(run_0_df["segment"].unique())/3)):
    print("i: " + str(i))
    fig = plt.figure(figsize=(15,4))
    ax = fig.add_subplot(1, 1, 1)
    plt.title('Spiral Search for Component {}'.format(i+1), fontsize=20)
    for index, seg in enumerate(run_0_df["segment"].unique()[i*3:(i+1)*3]):#[0:i*3]):
        if not index%3 == 2:
            continue
        print("-----")
        print(str(index) + ", " + str(index%3) + ", Seg: " + str(seg))
        t = run_0_df[run_0_df["segment"]==seg]
        x = t["pos_x"]
        y = t["pos_y"]
        z = t["pos_z"]
        ax = fig.add_subplot(1,1, 1)
        ax.plot(x, y, color = colors[2])
"""
    for index, seg in enumerate(run_0_df["segment"].unique()[i*3:(i+1)*3]):
        t = run_0_df[run_0_df["segment"]==seg]
        x = t["pos_x"]
        y = t["pos_y"]
        z = t["pos_z"]
        ax = fig.add_subplot(1,4, index%3, projection='3d' )
        ax.plot(x, y, z,color = colors[index])
    plt.tight_layout()"""
# Out:
# [ 11.  13.  14.  26.  28.  29.  41.  43.  44.  56.  58.  59.  75.  77.
#   78.  90.  92.  93. 105. 107. 108. 120. 122. 123.]
# i: 0
# -----
# 2, 2, Seg: 14.0
# i: 1
# -----
# 2, 2, Seg: 29.0
# i: 2
# -----
# 2, 2, Seg: 44.0
# i: 3
# -----
# 2, 2, Seg: 59.0
# i: 4
# -----
# 2, 2, Seg: 78.0
# i: 5
# -----
# 2, 2, Seg: 93.0
# i: 6
# -----
# 2, 2, Seg: 108.0
# i: 7
# -----
# 2, 2, Seg: 123.0
# '\n    for index, seg in enumerate(run_0_df["segment"].unique()[i*3:(i+1)*3]):\n        t = run_0_df[run_0_df["segment"]==seg]\n        x = t["pos_x"]\n        y = t["pos_y"]\n        z = t["pos_z"]\n        ax = fig.add_subplot(1,4, index%3, projection=\'3d\' )\n        ax.plot(x, y, z,color = colors[index])\n    plt.tight_layout()'

# %%
len(df["segment"].unique())
# Out:
# 1872

# %%
# take run == 0 as example
def plot_run(run: int, parameter:str):
    xl = parameter + "_x"
    yl = parameter + "_y"
    zl = parameter + "_z"
    df_temp = data[data["run"]==run]
    for i in range(int(len(df_temp["segment"].unique())/3)):
        fig = plt.figure(figsize=(15,4))
        ax = fig.add_subplot(1, 4, 1, projection='3d')
        plt.title('Inserting {} Component.'.format(i+1), fontsize=20)
        #ax.title.set_text('Inserting {} Component.'.format(i+1))
        # Plot the first column - Grey Lines
        for index, seg in enumerate(df_temp["segment"].unique()[0:i*3]):
            t = df_temp[df_temp["segment"]==seg]
            x = t[xl]
            y = t[yl]
            z = t[zl]

            ax.plot(x, y, z, color="tab:gray")
        # Plot the first column - Colored Lines
        for index, seg in enumerate(df_temp["segment"].unique()[i*3:(i+1)*3]):
            t = df_temp[df_temp["segment"]==seg]
            x = t[xl]
            y = t[yl]
            z = t[zl]

            ax.plot(x, y, z)

        # Plot Columns 1,2,3
        for index, seg in enumerate(df_temp["segment"].unique()[i*3:(i+1)*3]):
            t = df_temp[df_temp["segment"]==seg]
            x = t[xl]
            y = t[yl]
            z = t[zl]
            ax = fig.add_subplot(1,4, index%3+2, projection='3d' )
            ax.plot(x, y, z,color = colors[index])
        plt.tight_layout()

    #plt.savefig("{}.png".format(i),dpi=300,transparent=True)
plot_run(11, "pos")

# %%
xl = parameter + "_x"
yl = parameter + "_y"
zl = parameter + "_z"
df_temp = data[data["run"]==run]
for i in range(int(len(df_temp["segment"].unique())/3)):
    fig = plt.figure(figsize=(15,4))
    ax = fig.add_subplot(1, 4, 1, projection='3d')
    plt.title('Inserting {} Component.'.format(i+1), fontsize=20)
    #ax.title.set_text('Inserting {} Component.'.format(i+1))

# %%
# take run == 0 as example
def plot_run(run: int, parameter:str):
    xl = parameter + "_x"
    yl = parameter + "_y"
    zl = parameter + "_z"
    df_temp = data[data["run"]==run]
    for i in range(int(len(df_temp["segment"].unique())/3)):
        fig = plt.figure(figsize=(15,4))
        ax = fig.add_subplot(1, 4, 1, projection='3d')
        plt.title('Inserting {} Component.'.format(i+1), fontsize=20)
        #ax.title.set_text('Inserting {} Component.'.format(i+1))
        for index, seg in enumerate(df_temp["segment"].unique()[0:i*3]):
            t = df_temp[df_temp["segment"]==seg]
            x = t[xl]
            y = t[yl]
            z = t[zl]

            ax.plot(x, y, z, color="tab:gray")

        plt.tight_layout()

    #plt.savefig("{}.png".format(i),dpi=300,transparent=True)
plot_run(11, "pos")
